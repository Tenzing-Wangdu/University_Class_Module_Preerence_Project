# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/wangdu/Desktop/hybrid preference cis9665.csv") 
df.head()
#so what i did here was fist make a new excel file, copy only what is needed, and take the ranges out for 
# gpa , so instead of taking 3.2-3.4 i just took 3.2(left) and the right one for the post covid
#this makes it easier to plot the graph
# Out:
#    Pre-Covid  Post-Covid
# 0        3.4         3.7
# 1        3.4         3.7
# 2        3.8         3.3
# 3        3.8         4.0
# 4        3.4         3.7

# %%
plt.plot(df)
plt.legend(df) 
plt.ylabel("GPA", size=12)
plt.xlabel("CIS9665 Students", size =12)
plt.title("GPA change after covid-19")
plt.xticks(range(0,42,2))
plt.show()
plt.savefig("Change in GPA.png")
